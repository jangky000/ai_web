# %%
import pandas as pd
import os

# %%
# csv read
kto2 = pd.read_csv('./output/kto2.csv')
kto2.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객 비율(%)  \
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아       96.3
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아       98.2
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아       96.5
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아       97.5
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아       82.3
#
#    전체비율(%)
# 0     22.5
# 1      9.8
# 2      3.9
# 3      0.3
# 4      3.8

# %%
# 마지막 5개의 행 출력
kto2.tail()
# Out:
#           국적   관광   상용  공용  유학/연수     기타      계     기준년월     대륙  관광객 비율(%)  \
# 55    대양주 기타  555    3   4      0     52    614  2019-01  오세아니아       90.4
# 56  남아프리카공화국  368    9   1      6    616   1000  2019-01   아프리카       36.8
# 57   아프리카 기타  768  718  90    206    908   2690  2019-01   아프리카       28.6
# 58      국적미상   33    4   0      1     16     54  2019-01   기타대륙       61.1
# 59        교포    0    0   0      0  15526  15526  2019-01     교포        0.0
#
#     전체비율(%)
# 55      0.1
# 56      0.0
# 57      0.1
# 58      0.0
# 59      0.0

# %%
# 1년은 12개월의 구조를 가지고 있고, 해가 변경될 때마다 월이 반복되므로
# 함수로 제작할 필요가 있음
# 2010년 1월부터 2020년 3월까지의 데이터 통합

# %%
# 날짜를 기준으로 통합을 진행함.
# 2019-01, 자리수가 일치하지 않는 문제 발생(2 -> 02로 변경, ''.zfill(n) 사용)
for yy in range(2010, 2021): # 2010~2020
    for mm in range(1, 13): # 01~12
        yymm = '{0}-{1}'.format(yy, str(mm).zfill(2))
        print(yymm, '', end='')
# Out:
# 2010-01 2010-02 2010-03 2010-04 2010-05 2010-06 2010-07 2010-08 2010-09 2010-10 2010-11 2010-12 2011-01 2011-02 2011-03 2011-04 2011-05 2011-06 2011-07 2011-08 2011-09 2011-10 2011-11 2011-12 2012-01 2012-02 2012-03 2012-04 2012-05 2012-06 2012-07 2012-08 2012-09 2012-10 2012-11 2012-12 2013-01 2013-02 2013-03 2013-04 2013-05 2013-06 2013-07 2013-08 2013-09 2013-10 2013-11 2013-12 2014-01 2014-02 2014-03 2014-04 2014-05 2014-06 2014-07 2014-08 2014-09 2014-10 2014-11 2014-12 2015-01 2015-02 2015-03 2015-04 2015-05 2015-06 2015-07 2015-08 2015-09 2015-10 2015-11 2015-12 2016-01 2016-02 2016-03 2016-04 2016-05 2016-06 2016-07 2016-08 2016-09 2016-10 2016-11 2016-12 2017-01 2017-02 2017-03 2017-04 2017-05 2017-06 2017-07 2017-08 2017-09 2017-10 2017-11 2017-12 2018-01 2018-02 2018-03 2018-04 2018-05 2018-06 2018-07 2018-08 2018-09 2018-10 2018-11 2018-12 2019-01 2019-02 2019-03 2019-04 2019-05 2019-06 2019-07 2019-08 2019-09 2019-10 2019-11 2019-12 2020-01 2020-02 2020-03 2020-04 2020-05 2020-06 2020-07 2020-08 2020-09 2020-10 2020-11 2020-12

# %%
# 하나의 국가명을 전달 받아 대륙명을 리턴하는 함수
def getContinent(nation_name):
    continents = ''
    
    if "'일본', '대만', '홍콩', '마카오', '태국', \
        '말레이시아', '필리핀', '인도네시아',\
        '싱가포르', '미얀마', '베트남', '인도',\
        '스리랑카', '파키스탄', '방글라데시',\
        '캄보디아', '몽골', '중국', '이란', \
        '이스라엘', '터키', '우즈베키스탄', \
        '카자흐스탄', 'GCC', '아시아 기타'".find(nation_name) >= 0: 
        continents='아시아'
    elif "'미국', '캐나다', '멕시코', '브라질', \
         '미주 기타'".find(nation_name) >= 0: 
        continents='아메리카'
    elif "'영국', '독일', '프랑스', '네덜란드','스웨덴', '스위스', \
          '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아',\
          '스페인', '그리스', '포르투갈', '핀란드', '아일랜드',\
          '우크라이나', '러시아', '크로아티아', '루마니아',\
          '불가리아', '폴란드', '구주 기타'".find(nation_name) >= 0:
        continents='유럽'
    elif "'오스트레일리아', '뉴질랜드', '대양주 기타'".find(nation_name) >= 0:
        continents='오세아니아'         
    elif "'남아프리카공화국', '아프리카 기타'".find(nation_name) >= 0:
        continents='아프리카'
    elif "'국적미상'".find(nation_name) >= 0:
        continents='기타대륙'         
    elif "'교포'".find(nation_name) >= 0:
        continents='교포'
    else:
        print(nation_name + ' 발견 안됨')
        
    return continents

# %%
getContinent('중국')
# Out:
# '아시아'

# %%
def getContinents(df):
    continents = [] # 대륙명 저장
    for i in range(len(df)):
        nation_name = df.loc[i][0]
        # print(nation_name) # 국가명
        if "'일본', '대만', '홍콩', '마카오', '태국', \
            '말레이시아', '필리핀', '인도네시아',\
            '싱가포르', '미얀마', '베트남', '인도',\
            '스리랑카', '파키스탄', '방글라데시',\
            '캄보디아', '몽골', '중국', '이란', \
            '이스라엘', '터키', '우즈베키스탄', \
            '카자흐스탄', 'GCC', '아시아 기타'".find(nation_name) >= 0: 
            continents.append('아시아')
        elif "'미국', '캐나다', '멕시코', '브라질', \
             '미주 기타'".find(nation_name) >= 0: 
            continents.append('아메리카') 
        elif "'영국', '독일', '프랑스', '네덜란드','스웨덴', '스위스', \
              '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아',\
              '스페인', '그리스', '포르투갈', '핀란드', '아일랜드',\
              '우크라이나', '러시아', '크로아티아', '루마니아',\
              '불가리아', '폴란드', '구주 기타'".find(nation_name) >= 0:
            continents.append('유럽') 
        elif "'오스트레일리아', '뉴질랜드', '대양주 기타'".find(nation_name) >= 0:
            continents.append('오세아니아')         
        elif "'남아프리카공화국', '아프리카 기타'".find(nation_name) >= 0:
            continents.append('아프리카')  
        elif "'국적미상'".find(nation_name) >= 0:
            continents.append('기타대륙')          
        elif "'교포'".find(nation_name) >= 0:
            continents.append('교포')
    return continents
# getContinents(df)

# %%
# 년월을 입력 받아 DataFrame을 리턴하는 함수
def create_data(yy, mm):
    df = pd.DataFrame() # return 할 객체
    mm = str(mm).zfill(2) # 1 -> 01
    file_path = './data/kto_{0}{1}.xlsx'.format(yy, mm)
    if os.path.exists(file_path):
        df = pd.read_excel(file_path, header=1, skipfooter=4, usecols='A:G')
        
        # 기준년월 칼럼 추가
        df['기준년월'] = '{0}-{1}'.format(yy, mm)
        
        # 순수 국가명만 추출
        continents = ['아시아주', '미주', '구주', '대양주', \
                      '아프리카주', '기타대륙', '교포소계']
        df = df[df.국적.isin(continents) == False]
        df = df.reset_index(drop=True) # 다시 인덱스를 0부터 설정
        
        # 대륙 칼럼 추가
        df['대륙'] = getContinents(df)
        
        # 관광객 비율(%)
        df['관광객 비율(%)'] = round(df['관광']/df['계']*100, 1)
        
        # 관광 / 전체 관광객 * 100 = 전체비율(%)
        tour_sum= sum(df['관광'])
        df['전체비율(%)'] = round(df['관광']/tour_sum*100, 1)
# 46     우크라이나   214   30    2      7   377    630  2020-03     유럽       34.0
# 47       러시아  2189   42    4    115  2950   5300  2020-03     유럽       41.3
# 48     크로아티아    65    2    0      2    15     84  2020-03     유럽       77.4
# 49      루마니아    86    3    2      6    76    173  2020-03     유럽       49.7
# 50      불가리아    40    0    0      8    32     80  2020-03     유럽       50.0
# 51       폴란드   134   12    0     12   164    322  2020-03     유럽       41.6
# 52     구주 기타   257    1    3     63   214    538  2020-03     유럽       47.8
# 53   오스트레일리아   363   15    3     12   367    760  2020-03  오세아니아       47.8
# 54      뉴질랜드    90    3    4      4   174    275  2020-03  오세아니아       32.7
# 55    대양주 기타    16    0    2      0    32     50  2020-03  오세아니아       32.0
# 56  남아프리카공화국    29    0    0      0   208    237  2020-03   아프리카       12.2
# 57   아프리카 기타   103  134    6    145   558    946  2020-03   아프리카       10.9
# 58      국적미상     7    0    0      0     4     11  2020-03   기타대륙       63.6
# 59        교포     0    0    0      0  1615   1615  2020-03     교포        0.0
#
#     전체비율(%)
# 0      20.6
# 1       0.9
# 2       0.5
# 3       0.0
# 4       3.4
# 5       0.9
# 6       6.5
# 7       3.3
# 8       0.5
# 9       2.4
# 10      3.0
# 11      1.8
# 12      0.1
# 13      0.2
# 14      0.2
# 15      0.1
# 16      0.6
# 17     16.0
# 18      0.0
# 19      0.2
# 20      0.4
# 21      0.3
# 22      0.5
# 23      0.1
# 24      0.2
# 25     12.7
# 26      3.2
# 27      0.5
# 28      0.3
# 29      0.8
# 30      1.7
# 31      1.9
# 32      1.7
# 33      0.5
# 34      0.4
# 35      0.2
# 36      0.2
# 37      0.3
# 38      0.2
# 39      0.2
# 40      0.1
# 41      0.4
# 42      0.4
# 43      0.1
# 44      0.1
# 45      0.1
# 46      0.7
# 47      6.9
# 48      0.2
# 49      0.3
# 50      0.1
# 51      0.4
# 52      0.8
# 53      1.2
# 54      0.3
# 55      0.1
# 56      0.1
# 57      0.3
# 58      0.0
# 59      0.0

# %%
kto = pd.DataFrame()
for yy in range(2010, 2021): # 2010~2020
    for mm in range(1, 13): # 01~12
        rdf = create_data(yy, mm)
        kto = kto.append(rdf, ignore_index=True) # 원본 인덱스를 유지하지 않고, 계속 증가시킴

# %%
kto
# Out:
#             국적      관광    상용  공용  유학/연수    기타       계     기준년월     대륙  \
# 0           일본  202825  1750  89    549  3971  209184  2010-01    아시아
# 1           대만   35788    41  17     37   516   36399  2010-01    아시아
# 2           홍콩   13874    55   0     21   595   14545  2010-01    아시아
# 3          마카오     554     0   0      0     0     554  2010-01    아시아
# 4           태국   13374    39  13     53  4335   17814  2010-01    아시아
# ...        ...     ...   ...  ..    ...   ...     ...      ...    ...
# 7375    대양주 기타      16     0   2      0    32      50  2020-03  오세아니아
# 7376  남아프리카공화국      29     0   0      0   208     237  2020-03   아프리카
# 7377   아프리카 기타     103   134   6    145   558     946  2020-03   아프리카
# 7378      국적미상       7     0   0      0     4      11  2020-03   기타대륙
# 7379        교포       0     0   0      0  1615    1615  2020-03     교포
#
#       관광객 비율(%)  전체비율(%)
# 0          97.0     50.6
# 1          98.3      8.9
# 2          95.4      3.5
# 3         100.0      0.1
# 4          75.1      3.3
# ...         ...      ...
# 7375       32.0      0.1
# 7376       12.2      0.1
# 7377       10.9      0.3
# 7378       63.6      0.0
# 7379        0.0      0.0
#
# [7380 rows x 11 columns]

# %%
kto.to_csv('')
